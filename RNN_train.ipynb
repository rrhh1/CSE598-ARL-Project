# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader, Dataset

from sklearn.preprocessing import StandardScaler

import ast
import pandas as pd
import numpy as np

# %%
BATCH_SIZE = 30
EPOCH = 300
HIDDEN_SIZE = 32

# %%
df = pd.read_csv("new_dataset.csv")
data_target = np.asarray(df[["data", "target"]])
# np.random.shuffle(data_target)

train_X = data_target[:70, 0]
train_y = data_target[:70, 1]

valid_X = data_target[70:, 0]
valid_y = data_target[70:, 1]

for i in range(train_X.shape[0]):
    train_X[i] = np.asarray(ast.literal_eval(train_X[i]))
    min_val = train_X[i].min(axis=0)
    max_val = train_X[i].max(axis=0)

    train_X[i] = (train_X[i] - min_val) / (max_val - min_val)

for i in range(valid_X.shape[0]):
    valid_X[i] = np.asarray(ast.literal_eval(valid_X[i]))
    min_val = valid_X[i].min(axis=0)
    max_val = valid_X[i].max(axis=0)

    valid_X[i] = (valid_X[i] - min_val) / (max_val - min_val)

train_X = np.array([x for x in train_X])
train_y = np.asarray(train_y.reshape((-1, 1)) / 100, dtype=np.float32)

valid_X = np.array([x for x in valid_X])
valid_y = np.asarray(valid_y.reshape((-1, 1)) / 100, dtype=np.float32)

train_X = torch.from_numpy(train_X).float()
train_y = torch.from_numpy(train_y).float()
valid_X = torch.from_numpy(valid_X).float()
valid_y = torch.from_numpy(valid_y).float()


train_X
# Out:
# C:\Users\rayhu\AppData\Local\Temp\ipykernel_25088\2802333248.py:23: RuntimeWarning: invalid value encountered in divide
#   valid_X[i] = (valid_X[i] - min_val) / (max_val - min_val)
# tensor([[[0.0000, 1.0000, 0.0000],
#          [0.0000, 1.0000, 0.0000],
#          [0.3333, 0.6515, 0.0000],
#          ...,
#          [1.0000, 0.0000, 1.0000],
#          [1.0000, 0.0000, 1.0000],
#          [1.0000, 0.0000, 1.0000]],
#
#         [[0.0000, 1.0000, 1.0000],
#          [0.8904, 0.0000, 0.5312],
#          [0.9452, 0.2814, 0.6175],
#          ...,
#          [0.5616, 0.6287, 0.0234],
#          [0.5753, 0.5090, 0.0000],
#          [0.5753, 0.5090, 0.0000]],
#
#         [[0.0000, 1.0000, 1.0000],
#          [0.0000, 1.0000, 1.0000],
#          [0.3333, 0.6379, 0.2455],
#          ...,
#          [1.0000, 0.0000, 0.0000],
#          [1.0000, 0.0000, 0.0000],
#          [1.0000, 0.0000, 0.0000]],
#
#         ...,
#
#         [[1.0000, 1.0000, 1.0000],
#          [0.0000, 0.3779, 0.0057],
#          [0.0000, 0.3779, 0.0057],
#          ...,
#          [0.3846, 0.0000, 0.0671],
#          [0.3846, 0.0000, 0.0671],
#          [0.3846, 0.0000, 0.0671]],
#
#         [[1.0000, 1.0000, 1.0000],
#          [0.0000, 0.0392, 0.0000],
#          [0.0000, 0.0392, 0.0000],
#          ...,
#          [0.0195, 0.0000, 0.0148],
#          [0.0195, 0.0000, 0.0148],
#          [0.0195, 0.0000, 0.0148]],
#
#         [[1.0000, 1.0000, 1.0000],
#          [0.0000, 0.0816, 0.0000],
#          [0.0000, 0.0816, 0.0000],
#          ...,
#          [0.0138, 0.0000, 0.0000],
#          [0.0138, 0.0000, 0.0000],
#          [0.0138, 0.0000, 0.0000]]])

# %%
class CustomDataset(Dataset):
    def __init__(self, x, y):
        super().__init__()

        self.x = x
        self.y = y

    def __getitem__(self, index):
        
        x = torch.Tensor(self.x[index])
        y = torch.Tensor(self.y[index])

        return (x, y)
    
    def __len__(self):
        count = self.x.shape[0]
        return count

train_dataset = CustomDataset(train_X, train_y)
valid_dataset = CustomDataset(valid_X, valid_y)

train_dataloader = DataLoader(train_dataset, batch_size=BATCH_SIZE, shuffle=True)
valid_dataloader = DataLoader(valid_dataset, batch_size=BATCH_SIZE, shuffle=True)

# %%
class RNN_Model(nn.Module):
    def __init__(self, hidden_size):
        super().__init__()

        self.hidden_size = hidden_size
        self.num_layers = 2

        self.rnn = nn.RNN(
            input_size=3,
            hidden_size=self.hidden_size,
            num_layers=self.num_layers,
            nonlinearity='relu',
            bidirectional=False,
            batch_first=True
        )
        
        self.fc = nn.Sequential(
            nn.Linear(self.hidden_size, 32),
            nn.ReLU(),
            nn.Linear(32, 1),
        )
        

    def forward(self, x):
        h0 = torch.zeros(self.num_layers, x.size(0), self.hidden_size).to(x.device)
        x, _ = self.rnn(x)
        y = self.fc(x[:, -1, :])
        return y

# %%
device = 'cuda' if torch.cuda.is_available() else 'cpu'
model = RNN_Model(HIDDEN_SIZE).to(device)
criterion = nn.MSELoss().to(device)
optimizer = optim.AdamW(model.parameters(), lr=1e-4)


for epoch in range(EPOCH):
    train_loss = 0.0
    valid_loss = 0.0
    predicted_labels = []
    true_labels = []
    
    model.train()
    for inputs, labels in train_dataloader:
        inputs, labels = inputs.to(device), labels.to(device)

        optimizer.zero_grad()
        outputs = model(inputs)
        print(outputs)

        loss = criterion(outputs, labels)
        loss.backward()

        optimizer.step()
        train_loss += loss.item() * inputs.size(0)


    model.eval()
    with torch.no_grad():
        for inputs, labels in valid_dataloader:
            inputs, labels = inputs.to(device), labels.to(device)

            outputs = model(inputs)
            loss = criterion(outputs, labels)

            valid_loss += loss.item() * inputs.size(0)

    print(f"Epoch {epoch}")
    print(f"Average Training Loss: {train_loss / len(train_dataloader.sampler)}")
    print(f"Average Validation Loss: {valid_loss / len(valid_dataloader.sampler)}")
    # print(f"Validation Accuracy: {accuracy_score(true_labels, predicted_labels)}")

    # prfs = precision_recall_fscore_support(true_labels, predicted_labels, average='weighted')
    
    # print(f"Validation Precision: {prfs[0]}")
    # print(f"Validation Recall: {prfs[1]}")
    # print(f"Validation F1-Score: {prfs[2]}")

    print("==============================================================")
# Out:
# tensor([[0.0496],
#         [0.0496],
#         [0.0496],
#         [0.0477],
#         [0.0488],
#         [0.0498],
#         [0.0495],
#         [0.0496],
#         [0.0496],
#         [0.0488],
#         [0.0478],
#         [0.0496],
#         [0.0496],
#         [0.0461],
#         [0.0450],
#         [0.0488],
#         [0.0497],
#         [0.0496],
#         [0.0496],
#         [0.0521],
#         [0.0495],
#         [0.0496],
#         [0.0498],
#         [0.0496],
#         [0.0496],
#         [0.0497],
#         [0.0478],
#         [0.0508],
#         [0.0476],
#         [0.0513]], device='cuda:0', grad_fn=<AddmmBackward0>)
# tensor([[0.0500],
#         [0.0509],
#         [0.0505],
#         [0.0529],
#         [0.0530],
#         [0.0531],
#         [0.0505],
#         [0.0505],
#         [0.0522],
#         [0.0505],
#         [0.0479],
#         [0.0505],
#         [0.0498],
#         [0.0505],
#         [0.0505],
#         [0.0504],
#         [0.0505],
#         [0.0505],
#         [0.0506],
#         [0.0504],
#         [0.0524],
#         [0.0505],
#         [0.0441],
#         [0.0502],
#         [0.0486],
#         [0.0503],
#         [0.0527],
#         [0.0505],
#         [0.0508],
#         [0.0503]], device='cuda:0', grad_fn=<AddmmBackward0>)
# tensor([[0
], device='cuda:0', grad_fn=<AddmmBackward0>)
# tensor([[0.0645],
#         [0.0646],
#         [0.0671],
#         [0.0646],
#         [0.0622],
#         [0.0647],
#         [0.0672],
#         [0.0677],
#         [0.0623],
#         [0.0646]], device='cuda:0', grad_fn=<AddmmBackward0>)
# Epoch 5
# Average Training Loss: 0.3552710201059069
# Average Validation Loss: nan
# ==============================================================
# tensor([[0.0686],
#         [0.0667],
#         [0.0655],
#         [0.0650],
#         [0.0655],
#         [0.0654],
#         [0.0632],
#         [0.0655],
#         [0.0655],
#         [0.0656],
#         [0.0655],
#         [0.0649],
#         [0.0651],
#         [0.0655],
#         [0.0656],
#         [0.0658],
#         [0.0655],
#         [0.0633],
#         [0.0653],
#         [0.0681],
#         [0.0655],
#         [0.0658],
#         [0.0655],
#         [0.0655],
#         [0.0655],
#         [0.0655],
#         [0.0654],
#         [0.0686],
#         [0.0655],
#         [0.0655]], device='cuda:0', grad_fn=<AddmmBackward0>)
# tensor([[0.0688],
#         [0.0659],
#         [0.0659],
#         [0.0655],
#         [0.0690],
#         [0.0666],
#         [0.0662],
#         [0.0664],
#         [0.0662],
#         [0.0683],
#         [0.0657],
#         [0.0664],
#         [0.0664],
#         [0.0659],
#         [0.0664],
#         [0.0663],
#         [0.0661],
#         [0.0657],
#         [0.0664],
#         [0.0667],
#         [0.0668],
#         [0.0664],
#         [0.0669],
#         [0.0664],
#         [0.0638],
#         [0.0664],
#         [0.0689],
#         [0.0623],
#         [0.0648],
#         [0.0664]], device='cuda:0', grad_fn=<AddmmBackward0>)
# tensor([[0.0674],
#         [0.0672],
#         [0.0674],
#         [0.0698],
#         [0.0680],
#         [0.0673],
#         [0.0672],
#         [0.0696],
#         [0.0672],
#         [0.0679]], device='cuda:0', grad_fn=<AddmmBackward0>)
# Epoch 6
# Average Training Loss: 0.3523626370089395
# Average Validation Loss: nan
# ==============================================================
# tensor([[0.0675],
#         [0.0707],
#         [0.0679],
#         [0.0690],
#         [0.0688],
#         [0.0682],
#         [0.0682],
#         [0.0678],
#         [0.0707],
#         [0.0683],
#         [0.0681],
#         [0.0681],
#         [0.0681],
#         [0.0681],
#         [0.0693],
#         [0.0678],
#         [0.0714],
#         [0.0686],
#         [0.0682],
#         [0.0714],
#         [0.0681],
#         [0.0681],
#         [0.0682],
#         [0.0682],
#         [0.0681],
#         [0.0681],
#         [0.0672],
#         [0.0684],
#         [0.0681],
#         [0.0681]], device='cuda:0', grad_fn=<AddmmBackward0>)
# tensor([[0.0690],
#         [0.0686],
#         [0.0690],
#         [0.0689],
#         [0.0690],
#         [0.0666],
#         [0.0690],
#         [0.0690],
#         [0.0673],
#         [0.0690],
#         [0.0690],
#         [0.0715],
#         [0.0694],
#         [0.0718],
#         [0.0690],
#         [0.0696],
#         [0.0694],
#         [0.0690],
#         [0.0710],
#         [0.0694],
#         [0.0688],
#         [0.0689],
#         [0.0669],
#         [0.0690],
#         [0.0652],
#         [0.0688],
#         [0.0688],
#         [0.0716],
#         [0.0690],
#         [0.0690]], device='cuda:0', grad_fn=<AddmmBackward0>)
# tensor([[0.0697],
#         [0.0699],
#         [0.0697],
#         [0.0685],
#         [0.0699],
#         [0.0699],
#         [0.0695],
#         [0.0701],
#         [0.0726],
#         [0.0699]], device='cuda:0', grad_fn=<AddmmBackward0>)
# Epoch 7
# Average Training Loss: 0.3494971139090402
# Average Validation Loss: nan
# ==============================================================
# tensor([[0.0709],
#         [0.0708],
#         [0.0707],
#         [0.0708],
#         [0.0708],
#         [0.0713],
#         [0.0729],
#         [0.0712],
#         [0.0734],
#         [0.0699],
#         [0.0707],
#         [0.0710],
#         [0.0712],
#         [0.0693],
#         [0.0671],
#         [0.0685],
#         [0.0736],
#         [0.0718],
#         [0.0706],
#         [0.0733],
#         [0.0708],
#         [0.0706],
#         [0.0705],
#         [0.0707],
#         [0.0707],
#         [0.0707],
#         [0.0716],
#         [0.0709],
#         [0.0708],
#         [0.0708]], device='cuda:0', grad_fn=<AddmmBackward0>)
# tensor([[0.0716],
#         [0.0728],
#         [0.0712],
#         [0.0744],
#         [0.0718],
#         [0.0714],
#         [0.0719],
#         [0.0717],
#         [0.0703],
#         [0.0716],
#         [0.0717],
#         [0.0717],
#         [0.0751],
#         [0.0720],
#         [0.0697],
#         [0.0716],
#         [0.0716],
#         [0.0716],
#         [0.0744],
#         [0.0716],
#         [0.0714],
#         [0.0717],
#         [0.0716],
#         [0.0716],
#         [0.0716],
#         [0.0711],
#         [0.0717],
#         [0.0716],
#         [0.0716],
#         [0.0716]], device='cuda:0', grad_fn=<AddmmBackward0>)
# tensor([[0.0732],
#         [0.0725],
#         [0.0724],
#         [0.0725],
#         [0.0725],
#         [0.0752],
#         [0.0760],
#         [0.0725],
#         [0.0725],
#         [0.0727]], device='cuda:0', grad_fn=<AddmmBackward0>)
# Epoch 8
# Average Training Loss: 0.3464827239513397
# Average Validation Loss: nan
# ==============================================================
# tensor([[0.0764],
#         [0.0736],
#         [0.0734],
#         [0.0732],
#         [0.0733],
#         [0.0733],
#         [0.0733],
#         [0.0725],
#         [0.0733],
#         [0.0769],
#         [0.0736],
#         [0.0740],
#         [0.0733],
#         [0.0733],
#         [0.0734],
#         [0.0734],
#         [0.0734],
#         [0.0741],
#         [0.0734],
#         [0.0734],
#         [0.0734],
#         [0.0731],
#         [0.0700],
#         [0.0734],
#         [0.0761],
#         [0.0732],
#         [0.0722],
#         [0.0734],
#         [0.0733],
#         [0.0735]], device='cuda:0', grad_fn=<AddmmBackward0>)
# tensor([[0.0739],
#         [0.0742],
#         [0.0753],
#         [0.0744],
#         [0.0749],
#         [0.0743],
#         [0.0745],
#         [0.0745],
#         [0.0742],
#         [0.0748],
#         [0.0742],
#         [0.0742],
#         [0.0770],
#         [0.0765],
#         [0.0771],
#         [0.0742],
#         [0.0771],
#         [0.0734],
#         [0.0742],
#         [0.0756],
#         [0.0744],
#         [0.0747],
#         [0.0726],
#         [0.0737],
#         [0.0744],
#         [0.0742],
#         [0.0778],
#         [0.0743],
#         [0.0743],
#         [0.0742]], device='cuda:0', grad_fn=<AddmmBackward0>)
# tensor([[0.0766],
#         [0.0751],
#         [0.0757],
#         [0.0750],
#         [0.0780],
#         [0.0753],
#         [0.0753],
#         [0.0755],
#         [0.0751],
#         [0.0732]], device='cuda:0', grad_fn=<AddmmBackward0>)
# Epoch 9
# Average Training Loss: 0.34370274203164236
# Average Validation Loss: nan
# ==============================================================
# tensor([[0.0772],
#         [0.0762],
#         [0.0761],
#         [0.0762],
#         [0.0760],
#         [0.0788],
#         [0.0760],
#         [0.0789],
#         [0.0760],
#         [0.0765],
#         [0.0774],
#         [0.0763],
#         [0.0758],
#         [0.0755],
#         [0.0767],
#         [0.0760],
#         [0.0761],
#         [0.0763],
#         [0.0789],
#         [0.0760],
#         [0.0766],
#         [0.0788],
#         [0.0769],
#         [0.0761],
#         [0.0764],
#         [0.0760],
#         [0.0760],
#         [0.0766],
#         [0.0762],
#         [0.0763]], device='cuda:0', grad_fn=<AddmmBackward0>)
# tensor([[0.0769],
#         [0.0770],
#         [0.0768],
#         [0.0769],
#         [0.0760],
#         [0.0766],
#         [0.0798],
#         [0.0769],
#         [0.0763],
#         [0.0769],
#         [0.0800],
#         [0.0768],
#         [0.0768],
#         [0.0772],
#         [0.0792],
#         [0.0754],
#         [0.0806],
#         [0.0770],
#         [0.0772],
#         [0.0761],
#         [0.0769],
#         [0.0772],
#         [0.0769],
#         [0.0770],
#         [0.0773],
#         [0.0750],
#         [0.0785],
#         [0.0770],
#         [0.0769],
#         [0.0769]], device='cuda:0', grad_fn=<AddmmBackward0>)
# tensor([[0
# Average Validation Loss: nan
# ==============================================================
# tensor([[0.0844],
#         [0.0843],
#         [0.0842],
#         [0.0871],
#         [0.0847],
#         [0.0842],
#         [0.0833],
#         [0.0842],
#         [0.0869],
#         [0.0879],
#         [0.0829],
#         [0.0842],
#         [0.0844],
#         [0.0848],
#         [0.0840],
#         [0.0845],
#         [0.0847],
#         [0.0855],
#         [0.0861],
#         [0.0845],
#         [0.0842],
#         [0.0842],
#         [0.0838],
#         [0.0865],
#         [0.0848],
#         [0.0848],
#         [0.0842],
#         [0.0842],
#         [0.0851],
#         [0.0843]], device='cuda:0', grad_fn=<AddmmBackward0>)
# tensor([[0.0851],
#         [0.0858],
#         [0.0889],
#         [0.0849],
#         [0.0853],
#         [0.0851],
#         [0.0836],
#         [0.0851],
#         [0.0851],
#         [0.0852],
#         [0.0864],
#         [0.0852],
#         [0.0852],
#         [0.0851],
#         [0.0828],
#         [0.0881],
#         [0.0881],
#         [0.0854],
#         [0.0852],
#         [0.0848],
#         [0.0850],
#         [0.0858],
#         [0.0853],
#         [0.0878],
#         [0.0857],
#         [0.0851],
#         [0.0845],
#         [0.0858],
#         [0.0855],
#         [0.0851]], device='cuda:0', grad_fn=<AddmmBackward0>)
# tensor([[0.0862],
#         [0.0861],
#         [0.0863],
#         [0.0859],
#         [0.0888],
#         [0.0860],
#         [0.0868],
#         [0.0861],
#         [0.0861],
#         [0.0860]], device='cuda:0', grad_fn=<AddmmBackward0>)
# Epoch 13
# Average Training Loss: 0.3320642922605787
# Average Validation Loss: nan
# ==============================================================
# tensor([[0.0876],
#         [0.0870],
#         [0.0872],
#         [0.0897],
#         [0.0870],
#         [0.0869],
#         [0.0897],
#         [0.0870],
#         [0.0871],
#         [0.0872],
#         [0.0871],
#         [0.0877],
#         [0.0872],
#         [0.0876],
#         [0.0868],
#         [0.0866],
#         [0.0889],
#         [0.0870],
#         [0.0908],
#         [0.0870],
#         [0.0870],
#         [0.0873],
#         [0.0871],
#         [0.0877],
#         [0.0870],
#         [0.0883],
#         [0.0895],
#         [0.0871],
#         [0.0870],
#         [0.0869]], device='cuda:0', grad_fn=<AddmmBackward0>)
# tensor([[0.0877],
#         [0.0879],
#         [0.0877],
#         [0.0870],
#         [0.0860],
#         [0.0879],
#         [0.0887],
#         [0.0879],
#         [0.0906],
#         [0.0884],
#         [0.0909],
#         [0.0908],
#         [0.0879],
#         [0.0879],
#         [0.0909],
#         [0.0879],
#         [0.0879],
#         [0.0882],
#         [0.0916],
#         [0.0886],
#         [0.0879],
#         [0.0891],
#         [0.0873],
#         [0.0880],
#         [0.0879],
#         [0.0888],
#         [0.0887],
#         [0.0868],
#         [0.0877],
#         [0.0892]], device='cuda:0', grad_fn=<AddmmBackward0>)
# tensor([[0.0888],
#         [0.0897],
#         [0.0888],
#         [0.0886],
#         [0.0891],
#         [0.0890],
#         [0.0888],
#         [0.0875],
#         [0.0891],
#         [0.0896]], device='cuda:0', grad_fn=<AddmmBackward0>)
# Epoch 14
# Average Training Loss: 0.3291615971497127
# Average Validation Loss: nan
# ==============================================================
# tensor([[0.0898],
#         [0.0899],
#         [0.0926],
#         [0.0898],
#         [0.0898],
#         [0.0892],
#         [0.0898],
#         [0.0898],
#         [0.0912],
#         [0.0898],
#         [0.0895],
#         [0.0926],
#         [0.0904],
#         [0.0898],
#         [0.0881],
#         [0.0898],
#         [0.0900],
#         [0.0908],
#         [0.0900],
#         [0.0901],
#         [0.0889],
#         [0.0900],
#         [0.0901],
#         [0.0898],
#         [0.0936],
#         [0.0898],
#         [0.0898],
#         [0.0926],
#         [0.0899],
#         [0.0928]], device='cuda:0', grad_fn=<AddmmBackward0>)
# tensor([[0.0909],
#         [0.0934],
#         [0.0916],
#         [0.0922],
#         [0.0915],
#         [0.0909],
#         [0.0908],
#         [0.0908],
#         [0.0908],
#         [0.0908],
#         [0.0909],
#         [0.0907],
#         [0.0906],
#         [0.0917],
#         [0.0908],
#         [0.0908],
#         [0.0929],
#         [0.0916],
#         [0.0907],
#         [0.0916],
#         [0.0909],
#         [0.0908],
#         [0.0904],
#         [0.0916],
#         [0.0916],
#         [0.0910],
#         [0.0909],
#         [0.0919],
#         [0.0915],
#         [0.0917]], device='cuda:0', grad_fn=<AddmmBackward0>)
# tensor([[0.0906],
#         [0.0953],
#         [0.0945],
#         [0.0919],
#         [0.0931],
#         [0.0919],
#         [0.0947],
#         [0.0925],
#         [0.0921],
#         [0.0904]], device='cuda:0', grad_fn=<AddmmBackward0>)
# Epoch 15
# Average Training Loss: 0.32618402583258493
# Average Validation Loss: nan
# ==============================================================
# tensor([[0.0930],
#         [0.0930],
#         [0.0930],
#         [0.0950],
#         [0.0956],
#         [0.0956],
#         [0.0930],
#         [0.0930],
#         [0.0931],
#         [0.0936],
#         [0.0937],
#         [0.0944],
#         [0.0935],
#         [0.0932],
#         [0.0915],
#         [0.0957],
#         [0.0938],
#         [0.0930],
#         [0.0929],
#         [0.0929],
#         [0.0930],
#         [0.0929],
#         [0.0930],
#         [0.0920],
#         [0.0933],
#         [0.0959],
#         [0.0930],
#         [0.0937],
#         [0.0936],
#         [0.0927]], device='cuda:0', grad_fn=<AddmmBackward0>)
# tensor([[0.0937],
#         [0.0924],
#         [0.0953],
#         [0.0949],
#         [0.0942],
#         [0.0975],
#         [0.0941],
#         [0.0938],
#         [0.0941],
#         [0.0956],
#         [0.0945],
#         [0.0940],
#         [0.0941],
#         [0.0926],
#         [0.0941],
#         [0.0927],
#         [0.0947],
#         [0.0941],
#         [0.0941],
#         [0.0951],
#         [0.0941],
#         [0.0941],
#         [0.0966],
#         [0.0975],
#         [0.0944],
#         [0.0939],
#         [0.0942],
#         [0.0941],
#         [0.0943],
#         [0.0941]], device='cuda:0', grad_fn=<AddmmBackward0>)
# tensor([[0.0942],
#         [0.0952],
#         [0.0980],
#         [0.0955],
#         [0.0963],
#         [0.0980],
#         [0.0947],
#         [0.0952],
#         [0.0951],
#         [0.0952]], device='cuda:0', grad_fn=<AddmmBackward0>)
# Epoch 16
# Average Training Loss: 0.3228736094066075
# Average Validation Loss: nan
# ==============================================================
# tensor([[0.0964],
#         [0.0970],
#         [0.0975],
#         [0.0965],
#         [0.0946],
#         [0.0963],
#         [0.0967],
#         [0.0966],
#         [0.0966],
#         [0.0988],
#         [0.0964],
#         [0.0966],
#         [0.0963],
#         [0.0989],
#         [0.0948],
#         [0.0971],
#         [0.0954],
#         [0.0946],
#         [0.0969],
#         [0.0993],
#         [0.0963],
#         [0.0961],
#         [0.0964],
#         [0.0967],
#         [0.0964],
#         [0.0963],
#         [0.0992],
#         [0.0964],
#         [0.0964],
#         [0.0977]], device='cuda:0', grad_fn=<AddmmBackward0>)
# tensor([[0.0957],
#         [0.0988],
#         [0.0975],
#         [0.0975],
#         [0.0975],
#         [0.0983],
#         [0.0973],
#         [0.0974],
#         [0.0974],
#         [0.0975],
#         [0.0975],
#         [0.0975],
#         [0.0990],
#         [0.0976],
#         [0.0975],
#         [0.0974],
#         [0.0968],
#         [0.1009],
#         [0.1000],
#         [0.0976],
#         [0.0992],
#         [0.0978],
#         [0.1004],
#         [0.0975],
#         [0.0983],
#         [0.0975],
#         [0.0975],
#         [0.0975],
#         [0.0975],
#         [0.0975]], device='cuda:0', grad_fn=<AddmmBackward0>)
# tensor([[0.0986],
#         [0.1013],
#         [0.1014],
#         [0.0977],
#         [0.0986],
#         [0.0989],
#         [0.0983],
#         [0.0976],
#         [0.0986],
#         [0.0987]], device='cuda:0', grad_fn=<AddmmBackward0>)
# Epoch 17
# Average Training Loss: 0.3194182685443333
# Average Validation Loss: nan
# ==============================================================
# tensor([[0.0998],
#         [0.1001],
#         [0.0998],
#         [0.0989],
#         [0.0998],
#         [0.0998],
#         [0.0997],
#         [0.0997],
#         [0.1001],
#         [0.0998],
#         [0.1022],
#         [0.1014],
#         [0.1000],
#         [0.1027],
#         [0.1009],
#         [0.0977],
#         [0.0998],
#         [0.0998],
#         [0.0997],
#         [0.0998],
#         [0.0997],
#         [0.0998],
#         [0.0998],
#         [0.0998],
#         [0.1014],
#         [0.0998],
#         [0.0998],
#         [0.1011],
#         [0.0998],
#         [0.0998]], device='cuda:0', grad_fn=<AddmmBackward0>)
# tensor([[0.1010],
#         [0.1009],
#         [0.1038],
#         [0.1009],
#         [0.0988],
#         [0.1010],
#         [0.1008],
#         [0.1009],
#         [0.1012],
#         [0.1010],
#         [0.1010],
#         [0.1009],
#         [0.1015],
#         [0.1010],
#         [0.0998],
#         [0.1000],
#         [0.1007],
#         [0.0998],
#         [0.0991],
#         [0.1016],
#         [0.1006],
#         [0.1036],
#         [0.1034],
#         [0.1010],
#         [0.1014],
#         [0.1010],
#         [0.1024],
#         [0.1044],
#         [0.1009],
#         [0.1009]], device='cuda:0', grad_fn=<AddmmBackward0>)
# tensor([[0.1007],
#         [0.1030],
#         [0.1029],
#         [0.1051],
#         [0.1021],
#         [0.1047],
#         [0.1020],
#         [0.1019],
#         [0.1018],
#         [0.1047]], device='cuda:0', grad_fn=<AddmmBackward0>)
# Epoch 18
# Average Training Loss: 0.3160616712910788
# Average Validation Loss: nan
# ==============================================================
# tensor([[0.1037],
#         [0.1034],
#         [0.1058],
#         [0.1034],
#         [0.1059],
#         [0.1048],
#         [0.1051],
#         [0.1032],
#         [0.1024],
#         [0.1033],
#         [0.1047],
#         [0.1045],
#         [0.1061],
#         [0.1036],
#         [0.1060],
#         [0.1010],
#         [0.1057],
#         [0.1037],
#         [0.1034],
#         [0.1033],
#         [0.1063],
#         [0.1041],
#         [0.1033],
#         [0.1033],
#         [0.1033],
#         [0.1018],
#         [0.1014],
#         [0.1033],
#         [0.1033],
#         [0.1033]], device='cuda:0', grad_fn=<AddmmBackward0>)
# tensor([[0.1045],
#         [0.1045],
#         [0.1039],
#         [0.1039],
#         [0.1046],
#         [0.1047],
#         [0.1080],
#         [0.1045],
#         [0.1031],
#         [0.1047],
#         [0.1045],
#         [0.1038],
#         [0.1040],
#         [0.1045],
#         [0.1046],
#         [0.1046],
#         [0.1052],
#         [0.1046],
#         [0.1042],
#         [0.1042],
#         [0.1031],
#         [0.1045],
#         [0.1046],
#         [0.1045],
#         [0.1054],
#         [0.1045],
#         [0.1045],
#         [0.1045],
#         [0.1047],
#         [0.1045]], device='cuda:0', grad_fn=<AddmmBackward0>)
# tensor([[0.1057],
#         [0.1030],
#         [0.1054],
#         [0.1052],
#         [0.1087],
#         [0.1075],
#         [0.1062],
#         [0.1057],
#         [0.1084],
#         [0.1050]], device='cuda:0', grad_fn=<AddmmBackward0>)
# Epoch 19
# Average Training Loss: 0.31257551482745577
# Average Validation Loss: nan
# ==============================================================
# tensor([[0.1069],
#         [0.1056],
#         [0.1071],
#         [0.1069],
#         [0.1104],
#         [0.1082],
#         [0.1069],
#         [0.1078],
#         [0.1050],
#         [0.1062],
#         [0.1069],
#         [0.1070],
#         [0.1069],
#         [0.1092],
#         [0.1069],
#         [0.1066],
#         [0.1093],
#         [0.1069],
#         [0.1096],
#         [0.1069],
#         [0.1070],
#         [0.1061],
#         [0.1069],
#         [0.1087],
#         [0.1069],
#         [0.1068],
#         [0.1063],
#         [0.1070],
#         [0.1069],
#         [0.1093]], device='cuda:0', grad_fn=<AddmmBackward0>)
# tensor([[0
], device='cuda:0', grad_fn=<AddmmBackward0>)
# Epoch 22
# Average Training Loss: 0.3016698019845145
# Average Validation Loss: nan
# ==============================================================
# tensor([[0.1184],
#         [0.1184],
#         [0.1184],
#         [0.1181],
#         [0.1144],
#         [0.1180],
#         [0.1189],
#         [0.1174],
#         [0.1180],
#         [0.1200],
#         [0.1180],
#         [0.1212],
#         [0.1170],
#         [0.1172],
#         [0.1222],
#         [0.1163],
#         [0.1187],
#         [0.1169],
#         [0.1181],
#         [0.1179],
#         [0.1181],
#         [0.1202],
#         [0.1195],
#         [0.1181],
#         [0.1181],
#         [0.1181],
#         [0.1184],
#         [0.1181],
#         [0.1213],
#         [0.1145]], device='cuda:0', grad_fn=<AddmmBackward0>)
# tensor([[0.1193],
#         [0.1193],
#         [0.1223],
#         [0.1229],
#         [0.1193],
#         [0.1194],
#         [0.1187],
#         [0.1194],
#         [0.1194],
#         [0.1193],
#         [0.1199],
#         [0.1197],
#         [0.1193],
#         [0.1194],
#         [0.1188],
#         [0.1194],
#         [0.1222],
#         [0.1205],
#         [0.1185],
#         [0.1194],
#         [0.1163],
#         [0.1193],
#         [0.1177],
#         [0.1193],
#         [0.1180],
#         [0.1214],
#         [0.1197],
#         [0.1211],
#         [0.1191],
#         [0.1221]], device='cuda:0', grad_fn=<AddmmBackward0>)
# tensor([[0.1196],
#         [0.1206],
#         [0.1206],
#         [0.1229],
#         [0.1191],
#         [0.1207],
#         [0.1209],
#         [0.1211],
#         [0.1206],
#         [0.1206]], device='cuda:0', grad_fn=<AddmmBackward0>)
# Epoch 23
# Average Training Loss: 0.2979484796524048
# Average Validation Loss: nan
# ==============================================================
# tensor([[0.1219],
#         [0.1191],
#         [0.1210],
#         [0.1219],
#         [0.1211],
#         [0.1219],
#         [0.1219],
#         [0.1218],
#         [0.1219],
#         [0.1238],
#         [0.1242],
#         [0.1222],
#         [0.1215],
#         [0.1226],
#         [0.1223],
#         [0.1222],
#         [0.1219],
#         [0.1247],
#         [0.1251],
#         [0.1239],
#         [0.1228],
#         [0.1205],
#         [0.1223],
#         [0.1222],
#         [0.1212],
#         [0.1231],
#         [0.1219],
#         [0.1238],
#         [0.1219],
#         [0.1253]], device='cuda:0', grad_fn=<AddmmBackward0>)
# tensor([[0.1232],
#         [0.1227],
#         [0.1281],
#         [0.1232],
#         [0.1233],
#         [0.1232],
#         [0.1235],
#         [0.1245],
#         [0.1232],
#         [0.1254],
#         [0.1268],
#         [0.1231],
#         [0.1224],
#         [0.1219],
#         [0.1232],
#         [0.1237],
#         [0.1260],
#         [0.1232],
#         [0.1232],
#         [0.1232],
#         [0.1229],
#         [0.1198],
#         [0.1232],
#         [0.1226],
#         [0.1232],
#         [0.1232],
#         [0.1230],
#         [0.1232],
#         [0.1238],
#         [0.1236]], device='cuda:0', grad_fn=<AddmmBackward0>)
# tensor([[0.1244],
#         [0.1209],
#         [0.1245],
#         [0.1239],
#         [0.1246],
#         [0.1245],
#         [0.1233],
#         [0.1233],
#         [0.1275],
#         [0.1245]], device='cuda:0', grad_fn=<AddmmBackward0>)
# Epoch 24
# Average Training Loss: 0.2940660033907209
# Average Validation Loss: nan
# ==============================================================
# tensor([[0.1256],
#         [0.1262],
#         [0.1257],
#         [0.1258],
#         [0.1256],
#         [0.1257],
#         [0.1258],
#         [0.1258],
#         [0.1265],
#         [0.1254],
#         [0.1262],
#         [0.1257],
#         [0.1262],
#         [0.1257],
#         [0.1258],
#         [0.1258],
#         [0.1292],
#         [0.1257],
#         [0.1259],
#         [0.1257],
#         [0.1261],
#         [0.1257],
#         [0.1233],
#         [0.1258],
#         [0.1258],
#         [0.1258],
#         [0.1311],
#         [0.1257],
#         [0.1261],
#         [0.1258]], device='cuda:0', grad_fn=<AddmmBackward0>)
# tensor([[0.1282],
#         [0.1271],
#         [0.1292],
#         [0.1237],
#         [0.1277],
#         [0.1266],
#         [0.1279],
#         [0.1267],
#         [0.1270],
#         [0.1294],
#         [0.1271],
#         [0.1299],
#         [0.1308],
#         [0.1293],
#         [0.1271],
#         [0.1295],
#         [0.1259],
#         [0.1261],
#         [0.1275],
#         [0.1262],
#         [0.1272],
#         [0.1290],
#         [0.1300],
#         [0.1261],
#         [0.1262],
#         [0.1272],
#         [0.1268],
#         [0.1274],
#         [0.1302],
#         [0.1306]], device='cuda:0', grad_fn=<AddmmBackward0>)
# tensor([[0.1285],
#         [0.1285],
#         [0.1252],
#         [0.1279],
#         [0.1290],
#         [0.1297],
#         [0.1284],
#         [0.1284],
#         [0.1285],
#         [0.1282]], device='cuda:0', grad_fn=<AddmmBackward0>)
# Epoch 25
# Average Training Loss: 0.29026451281138826
# Average Validation Loss: nan
# ==============================================================
# tensor([[0.1265],
#         [0.1298],
#         [0.1298],
#         [0.1322],
#         [0.1322],
#         [0.1298],
#         [0.1291],
#         [0.1301],
#         [0.1297],
#         [0.1297],
#         [0.1298],
#         [0.1297],
#         [0.1334],
#         [0.1302],
#         [0.1321],
#         [0.1304],
#         [0.1297],
#         [0.1297],
#         [0.1300],
#         [0.1333],
#         [0.1293],
#         [0.1302],
#         [0.1298],
#         [0.1302],
#         [0.1296],
#         [0.1297],
#         [0.1356],
#         [0.1276],
#         [0.1290],
#         [0.1298]], device='cuda:0', grad_fn=<AddmmBackward0>)
# tensor([[0.1315],
#         [0.1311],
#         [0.1305],
#         [0.1315],
#         [0.1319],
#         [0.1311],
#         [0.1311],
#         [0.1313],
#         [0.1312],
#         [0.1349],
#         [0.1311],
#         [0.1309],
#         [0.1311],
#         [0.1303],
#         [0.1311],
#         [0.1280],
#         [0.1333],
#         [0.1311],
#         [0.1306],
#         [0.1315],
#         [0.1310],
#         [0.1312],
#         [0.1311],
#         [0.1312],
#         [0.1310],
#         [0.1311],
#         [0.1316],
#         [0.1332],
#         [0.1323],
#         [0.1318]], device='cuda:0', grad_fn=<AddmmBackward0>)
# tensor([[0.1355],
#         [0.1326],
#         [0.1326],
#         [0.1333],
#         [0.1339],
#         [0.1358],
#         [0.1314],
#         [0.1327],
#         [0.1324],
#         [0.1354]], device='cuda:0', grad_fn=<AddmmBackward0>)
# Epoch 26
# Average Training Loss: 0.2864143805844443
# Average Validation Loss: nan
# ==============================================================
# tensor([[0.1343],
#         [0.1378],
#         [0.1340],
#         [0.1340],
#         [0.1345],
#         [0.1339],
#         [0.1340],
#         [0.1353],
#         [0.1403],
#         [0.1319],
#         [0.1340],
#         [0.1335],
#         [0.1341],
#         [0.1334],
#         [0.1340],
#         [0.1339],
#         [0.1347],
#         [0.1339],
#         [0.1361],
#         [0.1364],
#         [0.1336],
#         [0.1337],
#         [0.1338],
#         [0.1338],
#         [0.1339],
#         [0.1364],
#         [0.1340],
#         [0.1330],
#         [0.1370],
#         [0.1340]], device='cuda:0', grad_fn=<AddmmBackward0>)
# tensor([[0.1354],
#         [0.1321],
#         [0.1354],
#         [0.1375],
#         [0.1354],
#         [0.1344],
#         [0.1360],
#         [0.1354],
#         [0.1347],
#         [0.1323],
#         [0.1354],
#         [0.1354],
#         [0.1355],
#         [0.1354],
#         [0.1359],
#         [0.1383],
#         [0.1354],
#         [0.1353],
#         [0.1364],
#         [0.1356],
#         [0.1353],
#         [0.1354],
#         [0.1386],
#         [0.1358],
#         [0.1361],
#         [0.1354],
#         [0.1356],
#         [0.1356],
#         [0.1356],
#         [0.1389]], device='cuda:0', grad_fn=<AddmmBackward0>)
# tensor([[0.1368],
#         [0.1363],
#         [0.1370],
#         [0.1368],
#         [0.1370],
#         [0.1406],
#         [0.1369],
#         [0.1393],
#         [0.1368],
#         [0.1373]], device='cuda:0', grad_fn=<AddmmBackward0>)
# Epoch 27
# Average Training Loss: 0.2822090621505465
# Average Validation Loss: nan
# ==============================================================
# tensor([[0.1385],
#         [0.1385],
#         [0.1383],
#         [0.1408],
#         [0.1380],
#         [0.1383],
#         [0.1408],
#         [0.1422],
#         [0.1385],
#         [0.1383],
#         [0.1363],
#         [0.1383],
#         [0.1384],
#         [0.1378],
#         [0.1415],
#         [0.1374],
#         [0.1396],
#         [0.1383],
#         [0.1383],
#         [0.1382],
#         [0.1383],
#         [0.1388],
#         [0.1383],
#         [0.1416],
#         [0.1351],
#         [0.1383],
#         [0.1383],
#         [0.1384],
#         [0.1387],
#         [0.1383]], device='cuda:0', grad_fn=<AddmmBackward0>)
# tensor([[0.1402],
#         [0.1438],
#         [0.1398],
#         [0.1432],
#         [0.1390],
#         [0.1398],
#         [0.1398],
#         [0.1398],
#         [0.1398],
#         [0.1398],
#         [0.1398],
#         [0.1408],
#         [0.1404],
#         [0.1398],
#         [0.1393],
#         [0.1468],
#         [0.1396],
#         [0.1403],
#         [0.1398],
#         [0.1397],
#         [0.1399],
#         [0.1398],
#         [0.1364],
#         [0.1401],
#         [0.1392],
#         [0.1393],
#         [0.1419],
#         [0.1398],
#         [0.1421],
#         [0.1419]], device='cuda:0', grad_fn=<AddmmBackward0>)
# tensor([[0.1413],
#         [0.1415],
#         [0.1444],
#         [0.1413],
#         [0.1424],
#         [0.1419],
#         [0.1418],
#         [0.1408],
#         [0.1413],
#         [0.1417]], device='cuda:0', grad_fn=<AddmmBackward0>)
# Epoch 28
# Average Training Loss: 0.27820547776562826
# Average Validation Loss: nan
# ==============================================================
# tensor([[0.1428],
#         [0.1433],
#         [0.1470],
#         [0.1428],
#         [0.1463],
#         [0.1428],
#         [0.1430],
#         [0.1432],
#         [0.1439],
#         [0.1428],
#         [0.1428],
#         [0.1428],
#         [0.1451],
#         [0.1437],
#         [0.1396],
#         [0.1501],
#         [0.1462],
#         [0.1428],
#         [0.1428],
#         [0.1440],
#         [0.1428],
#         [0.1428],
#         [0.1423],
#         [0.1428],
#         [0.1432],
#         [0.1428],
#         [0.1451],
#         [0.1424],
#         [0.1428],
#         [0.1429]], device='cuda:0', grad_fn=<AddmmBackward0>)
# tensor([[0.1444],
#         [0.1438],
#         [0.1444],
#         [0.1443],
#         [0.1444],
#         [0.1444],
#         [0.1484],
#         [0.1439],
#         [0.1444],
#         [0.1438],
#         [0.1456],
#         [0.1444],
#         [0.1479],
#         [0.1439],
#         [0.1444],
#         [0.1437],
#         [0.1449],
#         [0.1441],
#         [0.1444],
#         [0.1466],
#         [0.1443],
#         [0.1470],
#         [0.1444],
#         [0.1444],
#         [0.1444],
#         [0.1448],
#         [0.1446],
#         [0.1452],
#         [0.1450],
#         [0.1475]], device='cuda:0', grad_fn=<AddmmBackward0>)
# tensor([[0.1463],
#         [0.1463],
#         [0.1459],
#         [0.1461],
#         [0.1459],
#         [0.1486],
#         [0.1438],
#         [0.1459],
#         [0.1460],
#         [0.1424]], device='cuda:0', grad_fn=<AddmmBackward0>)
# Epoch 29
# Average Training Loss: 0.27388609307152884
# Average Validation Loss: nan
# ==============================================================
# tensor([[0.1477],
#         [0.1469],
#         [0.1476],
#         [0.1476],
#         [0.1476],
#         [0.1476],
#         [0.1500],
#         [0.1510],
#         [0.1476],
#         [0.1481],
#         [0.1473],
#         [0.1471],
#         [0.1476],
#         [0.1477],
#         [0.1486],
#         [0.1476],
#         [0.1471],
#         [0.1476],
#         [0.1476],
#         [0.1511],
#         [0.1517],
#         [0.1477],
#         [0.1473],
#         [0.1487],
#         [0.1476],
#         [0.1439],
#         [0.1498],
#         [0.1471],
#         [0.1496],
#         [0.1475]], device='cuda:0', grad_fn=<AddmmBackward0>)
# tensor([[0.1488],
#         [0.1494],
#         [0.1492],
#         [0.1492],
#         [0.1492],
#         [0.1455],
#         [0.1492],
#         [0.1518],
#         [0.1505],
#         [0.1496],
#         [0.1483],
#         [0.1525],
#         [0.1501],
#         [0.1492],
#         [0.1498],
#         [0.1570],
#         [0.1492],
#         [0.1492],
#         [0.1500],
#         [0.1524],
#         [0.1491],
#         [0.1504],
#         [0.1497],
#         [0.1536],
#         [0.1492],
#         [0.1493],
#         [0.1492],
#         [0.1493],
#         [0.1491],
#         [0.1496]], device='cuda:0', grad_fn=<AddmmBackward0>)
# tensor([[0.1509],
#         [0.1514],
#         [0.1508],
#         [0.1509],
#         [0.1485],
#         [0.1511],
#         [0.1509],
#         [0.1508],
#         [0.1507],
#         [0.1535]], device='cuda:0', grad_fn=<AddmmBackward0>)
# Epoch 30
# Average Training Loss: 0.2694340773991176
# Average Validation Loss: nan
# ==============================================================
# tensor([[0.1526],
#         [0.1525],
#         [0.1535],
#         [0.1528],
#         [0.1527],
#         [0.1524],
#         [0.1520],
#         [0.1527],
#         [0.1525],
#         [0.1548],
#         [0.1531],
#         [0.1525],
#         [0.1526],
#         [0.1527],
#         [0.1537],
#         [0.1526],
#         [0.1520],
#         [0.1567],
#         [0.1526],
#         [0.1525],
#         [0.1557],
#         [0.1525],
#         [0.1524],
# ...
#         [0.6457],
#         [0.5896],
#         [0.6552],
#         [0.6460],
#         [0.5954],
#         [0.6414],
#         [0.6008],
#         [0.6351],
#         [0.6432],
#         [0.6279],
#         [0.6491]], device='cuda:0', grad_fn=<AddmmBackward0>)
# tensor([[0.5889],
#         [0.5523],
#         [0.5392],
#         [0.6433],
#         [0.6555],
#         [0.5737],
#         [0.5280],
#         [0.5530],
#         [0.6504],
#         [0.5996]], device='cuda:0', grad_fn=<AddmmBackward0>)
# Epoch 289
# Average Training Loss: 0.05618668134723391
# Average Validation Loss: nan
# ==============================================================
# tensor([[0.6498],
#         [0.6106],
#         [0.5741],
#         [0.6326],
#         [0.5526],
#         [0.5959],
#         [0.6362],
#         [0.6562],
#         [0.5894],
#         [0.6525],
#         [0.5907],
#         [0.5440],
#         [0.6483],
#         [0.6465],
#         [0.5842],
#         [0.6562],
#         [0.6539],
#         [0.6535],
#         [0.6498],
#         [0.5940],
#         [0.5633],
#         [0.6517],
#         [0.6422],
#         [0.5946],
#         [0.6562],
#         [0.6515],
#         [0.6325],
#         [0.6501],
#         [0.6468],
#         [0.6375]], device='cuda:0', grad_fn=<AddmmBackward0>)
# tensor([[0.6211],
#         [0.6440],
#         [0.5853],
#         [0.6116],
#         [0.6399],
#         [0.6426],
#         [0.6563],
#         [0.6480],
#         [0.5394],
#         [0.6038],
#         [0.5395],
#         [0.5789],
#         [0.5812],
#         [0.6519],
#         [0.6368],
#         [0.6558],
#         [0.5697],
#         [0.5857],
#         [0.6012],
#         [0.6468],
#         [0.6449],
#         [0.5982],
#         [0.6115],
#         [0.5999],
#         [0.5441],
#         [0.6511],
#         [0.6443],
#         [0.5897],
#         [0.6392],
#         [0.5535]], device='cuda:0', grad_fn=<AddmmBackward0>)
# tensor([[0.6006],
#         [0.6288],
#         [0.5799],
#         [0.5281],
#         [0.5280],
#         [0.5898],
#         [0.6503],
#         [0.6565],
#         [0.6443],
#         [0.5532]], device='cuda:0', grad_fn=<AddmmBackward0>)
# Epoch 290
# Average Training Loss: 0.05616449884005955
# Average Validation Loss: nan
# ==============================================================
# tensor([[0.5792],
#         [0.6572],
#         [0.5963],
#         [0.5635],
#         [0.6488],
#         [0.6218],
#         [0.6383],
#         [0.5803],
#         [0.5283],
#         [0.5947],
#         [0.6018],
#         [0.5534],
#         [0.5443],
#         [0.5861],
#         [0.5283],
#         [0.5956],
#         [0.6509],
#         [0.5898],
#         [0.6408],
#         [0.6545],
#         [0.5821],
#         [0.5396],
#         [0.6375],
#         [0.5441],
#         [0.6508],
#         [0.6434],
#         [0.6525],
#         [0.6510],
#         [0.6535],
#         [0.6449]], device='cuda:0', grad_fn=<AddmmBackward0>)
# tensor([[0.6572],
#         [0.6567],
#         [0.5986],
#         [0.6335],
#         [0.6431],
#         [0.6449],
#         [0.6452],
#         [0.6333],
#         [0.6373],
#         [0.6528],
#         [0.6572],
#         [0.6401],
#         [0.6124],
#         [0.5862],
#         [0.5395],
#         [0.5851],
#         [0.6013],
#         [0.5917],
#         [0.6549],
#         [0.6004],
#         [0.6043],
#         [0.5536],
#         [0.5525],
#         [0.6110],
#         [0.6520],
#         [0.6476],
#         [0.6527],
#         [0.5745],
#         [0.6572],
#         [0.5905]], device='cuda:0', grad_fn=<AddmmBackward0>)
# tensor([[0.6296],
#         [0.6479],
#         [0.5903],
#         [0.6578],
#         [0.6127],
#         [0.6496],
#         [0.6480],
#         [0.5701],
#         [0.6462],
#         [0.6512]], device='cuda:0', grad_fn=<AddmmBackward0>)
# Epoch 291
# Average Training Loss: 0.05616105294653347
# Average Validation Loss: nan
# ==============================================================
# tensor([[0.6455],
#         [0.6020],
#         [0.6440],
#         [0.6413],
#         [0.5989],
#         [0.5925],
#         [0.6535],
#         [0.6579],
#         [0.5439],
#         [0.5804],
#         [0.6556],
#         [0.5700],
#         [0.5394],
#         [0.6008],
#         [0.6527],
#         [0.5899],
#         [0.6552],
#         [0.5913],
#         [0.5751],
#         [0.6021],
#         [0.5952],
#         [0.6498],
#         [0.5280],
#         [0.6481],
#         [0.5635],
#         [0.5537],
#         [0.6222],
#         [0.6514],
#         [0.6494],
#         [0.5441]], device='cuda:0', grad_fn=<AddmmBackward0>)
# tensor([[0.6406],
#         [0.5899],
#         [0.6433],
#         [0.6530],
#         [0.6570],
#         [0.6384],
#         [0.6109],
#         [0.6512],
#         [0.6341],
#         [0.5787],
#         [0.6576],
#         [0.6129],
#         [0.5520],
#         [0.6333],
#         [0.6576],
#         [0.5960],
#         [0.5964],
#         [0.6454],
#         [0.6128],
#         [0.5858],
#         [0.5827],
#         [0.5387],
#         [0.5274],
#         [0.5857],
#         [0.6479],
#         [0.6042],
#         [0.6538],
#         [0.6576],
#         [0.6379],
#         [0.6376]], device='cuda:0', grad_fn=<AddmmBackward0>)
# tensor([[0.6513],
#         [0.6579],
#         [0.6462],
#         [0.6454],
#         [0.5528],
#         [0.6513],
#         [0.6296],
#         [0.5872],
#         [0.6480],
#         [0.6529]], device='cuda:0', grad_fn=<AddmmBackward0>)
# Epoch 292
# Average Training Loss: 0.056166526462350576
# Average Validation Loss: nan
# ==============================================================
# tensor([[0.5912],
#         [0.6508],
#         [0.5428],
#         [0.6572],
#         [0.6020],
#         [0.6329],
#         [0.5267],
#         [0.5962],
#         [0.5979],
#         [0.5527],
#         [0.5746],
#         [0.5890],
#         [0.6010],
#         [0.6572],
#         [0.5893],
#         [0.6379],
#         [0.5851],
#         [0.5266],
#         [0.6104],
#         [0.6475],
#         [0.6523],
#         [0.6548],
#         [0.6507],
#         [0.6380],
#         [0.6487],
#         [0.5924],
#         [0.5381],
#         [0.5856],
#         [0.6405],
#         [0.6534]], device='cuda:0', grad_fn=<AddmmBackward0>)
# tensor([[0.6487],
#         [0.6211],
#         [0.6472],
#         [0.6570],
#         [0.6525],
#         [0.6445],
#         [0.6128],
#         [0.6446],
#         [0.6430],
#         [0.6570],
#         [0.6504],
#         [0.5422],
#         [0.5996],
#         [0.6448],
#         [0.6524],
#         [0.6565],
#         [0.6427],
#         [0.6126],
#         [0.5778],
#         [0.6453],
#         [0.5791],
#         [0.6369],
#         [0.5947],
#         [0.6034],
#         [0.5376],
#         [0.5620],
#         [0.5823],
#         [0.6570],
#         [0.5510],
#         [0.5865]], device='cuda:0', grad_fn=<AddmmBackward0>)
# tensor([[0.5678],
#         [0.5945],
#         [0.6464],
#         [0.6394],
#         [0.6535],
#         [0.6510],
#         [0.6330],
#         [0.5510],
#         [0.6497],
#         [0.6280]], device='cuda:0', grad_fn=<AddmmBackward0>)
# Epoch 293
# Average Training Loss: 0.056112970624651225
# Average Validation Loss: nan
# ==============================================================
# tensor([[0.5247],
#         [0.5245],
#         [0.5604],
#         [0.6355],
#         [0.5938],
#         [0.6457],
#         [0.6557],
#         [0.6312],
#         [0.6532],
#         [0.6557],
#         [0.5842],
#         [0.5875],
#         [0.6492],
#         [0.6511],
#         [0.6557],
#         [0.6020],
#         [0.5493],
#         [0.6458],
#         [0.6551],
#         [0.6491],
#         [0.6324],
#         [0.5936],
#         [0.6435],
#         [0.5732],
#         [0.6389],
#         [0.6557],
#         [0.6529],
#         [0.6416],
#         [0.6118],
#         [0.5853]], device='cuda:0', grad_fn=<AddmmBackward0>)
# tensor([[0.5807],
#         [0.6366],
#         [0.6193],
#         [0.6554],
#         [0.6437],
#         [0.5945],
#         [0.6508],
#         [0.5496],
#         [0.5354],
#         [0.5977],
#         [0.5757],
#         [0.6516],
#         [0.6411],
#         [0.6002],
#         [0.5829],
#         [0.5503],
#         [0.6269],
#         [0.6386],
#         [0.5988],
#         [0.5355],
#         [0.6428],
#         [0.6113],
#         [0.5909],
#         [0.6487],
#         [0.6504],
#         [0.6430],
#         [0.5401],
#         [0.5771],
#         [0.6082],
#         [0.6455]], device='cuda:0', grad_fn=<AddmmBackward0>)
# tensor([[0.5865],
#         [0.5894],
#         [0.5394],
#         [0.5660],
#         [0.6464],
#         [0.6498],
#         [0.6486],
#         [0.6467],
#         [0.6358],
#         [0.5952]], device='cuda:0', grad_fn=<AddmmBackward0>)
# Epoch 294
# Average Training Loss: 0.05607195251754352
# Average Validation Loss: nan
# ==============================================================
# tensor([[0.6491],
#         [0.6484],
#         [0.6491],
#         [0.5484],
#         [0.6472],
#         [0.6537],
#         [0.5969],
#         [0.5937],
#         [0.6415],
#         [0.6470],
#         [0.5884],
#         [0.6508],
#         [0.6419],
#         [0.6511],
#         [0.6303],
#         [0.5216],
#         [0.6291],
#         [0.5835],
#         [0.6537],
#         [0.6531],
#         [0.5713],
#         [0.6394],
#         [0.6471],
#         [0.6370],
#         [0.6063],
#         [0.5823],
#         [0.6452],
#         [0.6100],
#         [0.5793],
#         [0.6368]], device='cuda:0', grad_fn=<AddmmBackward0>)
# tensor([[0.5889],
#         [0.5209],
#         [0.5635],
#         [0.5987],
#         [0.6429],
#         [0.5369],
#         [0.5726],
#         [0.6092],
#         [0.5924],
#         [0.5980],
#         [0.6346],
#         [0.6477],
#         [0.5322],
#         [0.6491],
#         [0.6529],
#         [0.5465],
#         [0.5842],
#         [0.6388],
#         [0.5367],
#         [0.5840],
#         [0.6402],
#         [0.6529],
#         [0.6441],
#         [0.5741],
#         [0.6460],
#         [0.6243],
#         [0.6529],
#         [0.6334],
#         [0.5321],
#         [0.5911]], device='cuda:0', grad_fn=<AddmmBackward0>)
# tensor([[0.5934],
#         [0.5890],
#         [0.5438],
#         [0.6150],
#         [0.6417],
#         [0.6413],
#         [0.6309],
#         [0.5786],
#         [0.5555],
#         [0.6391]], device='cuda:0', grad_fn=<AddmmBackward0>)
# Epoch 295
# Average Training Loss: 0.05604673336659159
# Average Validation Loss: nan
# ==============================================================
# tensor([[0.6461],
#         [0.5904],
#         [0.6461],
#         [0.5895],
#         [0.5427],
#         [0.6220],
#         [0.6470],
#         [0.6454],
#         [0.5963],
#         [0.5768],
#         [0.6508],
#         [0.6364],
#         [0.5964],
#         [0.6508],
#         [0.6076],
#         [0.6438],
#         [0.6338],
#         [0.5798],
#         [0.6409],
#         [0.6366],
#         [0.6405],
#         [0.5440],
#         [0.6142],
#         [0.6260],
#         [0.5296],
#         [0.6385],
#         [0.5453],
#         [0.6479],
#         [0.5718],
#         [0.5817]], device='cuda:0', grad_fn=<AddmmBackward0>)
# tensor([[0.6266],
#         [0.5926],
#         [0.5286],
#         [0.6500],
#         [0.6324],
#         [0.6447],
#         [0.5901],
#         [0.6293],
#         [0.5537],
#         [0.6431],
#         [0.6435],
#         [0.6494],
#         [0.5174],
#         [0.5916],
#         [0.6399],
#         [0.5682],
#         [0.5809],
#         [0.5855],
#         [0.5769],
#         [0.5872],
#         [0.5603],
#         [0.6473],
#         [0.6500],
#         [0.5804],
#         [0.5868],
#         [0.6069],
#         [0.6380],
#         [0.5333],
#         [0.5332],
#         [0.6376]], device='cuda:0', grad_fn=<AddmmBackward0>)
# tensor([[0.6497],
#         [0.6429],
#         [0.6301],
#         [0.6369],
#         [0.6409],
#         [0.5163],
#         [0.6408],
#         [0.6017],
#         [0.6333],
#         [0.5688]], device='cuda:0', grad_fn=<AddmmBackward0>)
# Epoch 296
# Average Training Loss: 0.0560353829392365
# Average Validation Loss: nan
# ==============================================================
# tensor([[0.6364],
#         [0.5521],
#         [0.6059],
#         [0.6364],
#         [0.6434],
#         [0.5429],
#         [0.5268],
#         [0.6420],
#         [0.6423],
#         [0.5881],
#         [0.6359],
#         [0.6317],
#         [0.6441],
#         [0.6458],
#         [0.5941],
#         [0.5314],
#         [0.6482],
#         [0.6488],
#         [0.5880],
#         [0.6366],
#         [0.5399],
#         [0.6449],
#         [0.6006],
#         [0.5781],
#         [0.5268],
#         [0.6488],
#         [0.6291],
#         [0.6460],
#         [0.6399],
#         [0.6488]], device='cuda:0', grad_fn=<AddmmBackward0>)
# tensor([[0.5785],
#         [0.6271],
#         [0.5747],
#         [0.5401],
#         [0.6410],
#         [0.6381],
#         [0.5145],
#         [0.5139],
#         [0.6247],
#         [0.5305],
#         [0.6111],
#         [0.5667],
#         [0.5902],
#         [0.6310],
#         [0.6319],
#         [0.6338],
#         [0.5848],
#         [0.5665],
#         [0.6480],
#         [0.5789],
#         [0.5854],
#         [0.6231],
#         [0.5841],
#         [0.5886],
#         [0.6055],
#         [0.6378],
#         [0.6390],
#         [0.5940],
#         [0.5893],
#         [0.6480]], device='cuda:0', grad_fn=<AddmmBackward0>)
# tensor([[0.6186],
#         [0.6371],
#         [0.5572],
#         [0.6422],
#         [0.5778],
#         [0.6428],
#         [0.6331],
#         [0.5678],
#         [0.5740],
#         [0.6403]], device='cuda:0', grad_fn=<AddmmBackward0>)
# Epoch 297
# Average Training Loss: 0.056020620678152354
# Average Validation Loss: nan
# ==============================================================
# tensor([[0.6411],
#         [0.6267],
#         [0.5876],
#         [0.5494],
#         [0.5238],
#         [0.6341],
#         [0.6417],
#         [0.5777],
#         [0.5282],
#         [0.6306],
#         [0.5381],
#         [0.6175],
#         [0.6041],
#         [0.5764],
#         [0.5855],
#         [0.5885],
#         [0.6394],
#         [0.5830],
#         [0.5980],
#         [0.5831],
#         [0.5875],
#         [0.6465],
#         [0.6375],
#         [0.6375],
#         [0.6436],
#         [0.6363],
#         [0.6465],
#         [0.5767],
#         [0.6435],
#         [0.5654]], device='cuda:0', grad_fn=<AddmmBackward0>)
# tensor([[0.5909],
#         [0.5116],
#         [0.6420],
#         [0.5659],
#         [0.6412],
#         [0.6459],
#         [0.5761],
#         [0.6208],
#         [0.5277],
#         [0.5553],
#         [0.5923],
#         [0.6385],
#         [0.6452],
#         [0.5643],
#         [0.6287],
#         [0.6088],
#         [0.5722],
#         [0.6353],
#         [0.6039],
#         [0.5110],
#         [0.5729],
#         [0.6390],
#         [0.6336],
#         [0.6459],
#         [0.5859],
#         [0.5394],
#         [0.6227],
#         [0.6394],
#         [0.5229],
#         [0.6316]], device='cuda:0', grad_fn=<AddmmBackward0>)
# tensor([[0.6327],
#         [0.6396],
#         [0.6321],
#         [0.5830],
#         [0.6289],
#         [0.6351],
#         [0.6240],
#         [0.5350],
#         [0.6450],
#         [0.6305]], device='cuda:0', grad_fn=<AddmmBackward0>)
# Epoch 298
# Average Training Loss: 0.05602151261908667
# Average Validation Loss: nan
# ==============================================================
# tensor([[0.5472],
#         [0.5380],
#         [0.5260],
#         [0.6440],
#         [0.5960],
#         [0.5539],
#         [0.5763],
#         [0.5708],
#         [0.5748],
#         [0.6075],
#         [0.6196],
#         [0.5749],
#         [0.6032],
#         [0.6393],
#         [0.5093],
#         [0.5835],
#         [0.5896],
#         [0.5817],
#         [0.6447],
#         [0.5810],
#         [0.6156],
#         [0.5211],
#         [0.6028],
#         [0.6382],
#         [0.6408],
#         [0.5343],
#         [0.6301],
#         [0.6447],
#         [0.6356],
#         [0.6248]], device='cuda:0', grad_fn=<AddmmBackward0>)
# tensor([[0.6321],
#         [0.6233],
#         [0.5206],
#         [0.6314],
#         [0.5640],
#         [0.6272],
#         [0.6389],
#         [0.6341],
#         [0.6353],
#         [0.6398],
#         [0.5640],
#         [0.5831],
#         [0.6345],
#         [0.6414],
#         [0.6217],
#         [0.5623],
#         [0.6396],
#         [0.6375],
#         [0.6321],
#         [0.6444],
#         [0.5741],
#         [0.6290],
#         [0.6319],
#         [0.6293],
#         [0.5852],
#         [0.5092],
#         [0.6338],
#         [0.5250],
#         [0.6372],
#         [0.6301]], device='cuda:0', grad_fn=<AddmmBackward0>)
# tensor([[0.5728],
#         [0.5351],
#         [0.6449],
#         [0.5869],
#         [0.5923],
#         [0.6419],
#         [0.5861],
#         [0.6449],
#         [0.6374],
#         [0.5862]], device='cuda:0', grad_fn=<AddmmBackward0>)
# Epoch 299
# Average Training Loss: 0.05605494709951537
# Average Validation Loss: nan
# ==============================================================

# %%
data = torch.tensor([[283, 174, 9.486932754516602], [283, 174, 9.486932754516602], [283, 174, 9.486932754516602], [284, 154, 9.486932754516602], [284, 154, 9.486932754516602], [284, 154, 9.486932754516602], [284, 154, 9.486932754516602], [284, 154, 9.486932754516602], [289, 120, 9.962529182434082], [289, 120, 9.962529182434082]], dtype=torch.float32)
data = nn.functional.normalize(data)

data = data.view(1, 10, 3).to(device)
print(data.shape)
output = model(data)

output * 100
# Out:
# torch.Size([1, 10, 3])
# tensor([[59.2294]], device='cuda:0', grad_fn=<MulBackward0>)

# %%
for datum in valid_dataloader:
    print(model(datum[0].to(device)) * 100)
# Out:
# tensor([[55.7316],
#         [50.3786],
#         [58.6183],
#         [63.6509],
#         [49.5912],
#         [64.3808],
#         [56.2715],
#         [59.9591],
#         [50.6802],
#         [62.6680],
#         [59.5343],
#         [63.2404],
#         [    nan],
#         [51.4824],
#         [60.9550]], device='cuda:0', grad_fn=<MulBackward0>)

# %%
torch.save(model, "RNN_model.pth")

# %%
from joblib import dump, load
dump(ss, 'std_scaler.bin', compress=True)
# Out:
# ['std_scaler.bin']
